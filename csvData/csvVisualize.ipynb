# %%
#data analysis libraries 
import numpy as np
import pandas as pd

# %% [markdown]
# # covid_19_data.csv
#
# from: https://www.kaggle.com/sudalairajkumar/novel-corona-virus-2019-dataset
#
# columes description belows:
#
# * Sno - Serial number
# * ObservationDate - Date of the observation in MM/DD/YYYY
# * Province/State - Province or state of the observation (Could be empty when missing)
# * Country/Region - Country of observation
# * Last Update - Time in UTC at which the row is updated for the given province or country. (Not standardised and so please clean before using it)
# * Confirmed - Cumulative number of confirmed cases till that date
# * Deaths - Cumulative number of of deaths till that date
# * Recovered - Cumulative number of recovered cases till that date
#
# 各國家與省份的確診統計

# %%
covid_19_data = pd.read_csv("./covid_19_data.csv")

covid_19_data.describe(include="all")
# Out:
#                   SNo ObservationDate Province/State Country/Region  \
# count   156292.000000          156292         111979         156292
# unique            NaN             299            733            226
# top               NaN      11/12/2020        Unknown             US
# freq              NaN             758           1484          15430
# mean     78146.500000             NaN            NaN            NaN
# std      45117.758473             NaN            NaN            NaN
# min          1.000000             NaN            NaN            NaN
# 25%      39073.750000             NaN            NaN            NaN
# 50%      78146.500000             NaN            NaN            NaN
# 75%     117219.250000             NaN            NaN            NaN
# max     156292.000000             NaN            NaN            NaN
#
#                 Last Update     Confirmed         Deaths     Recovered
# count                156292  1.562920e+05  156292.000000  1.562920e+05
# ...

# %%
covid_19_data.head(10)
# Out:
#    SNo ObservationDate Province/State  Country/Region      Last Update  \
# 0    1      01/22/2020          Anhui  Mainland China  1/22/2020 17:00
# 1    2      01/22/2020        Beijing  Mainland China  1/22/2020 17:00
# 2    3      01/22/2020      Chongqing  Mainland China  1/22/2020 17:00
# 3    4      01/22/2020         Fujian  Mainland China  1/22/2020 17:00
# 4    5      01/22/2020          Gansu  Mainland China  1/22/2020 17:00
# 5    6      01/22/2020      Guangdong  Mainland China  1/22/2020 17:00
# 6    7      01/22/2020        Guangxi  Mainland China  1/22/2020 17:00
# 7    8      01/22/2020        Guizhou  Mainland China  1/22/2020 17:00
# 8    9      01/22/2020         Hainan  Mainland China  1/22/2020 17:00
# 9   10      01/22/2020          Hebei  Mainland China  1/22/2020 17:00
#
#    Confirmed  Deaths  Recovered
# 0        1.0     0.0        0.0
# 1       14.0     0.0        0.0
# 2        6.0     0.0        0.0
# 3        1.0     0.0        0.0
# ...

# %%
covid_19_data.shape
# Out:
# (156292, 8)

# %% [markdown]
# # COVID19_line_list_data.csv
#
# 自1/20/2020 ～ 2/28/2020 確診詳細案例 (未按順序排列)

# %%
COVID19_line_list_data = pd.read_csv("./COVID19_line_list_data.csv")

COVID19_line_list_data.describe(include="all")
# Out:
#                  id  case_in_country reporting date  Unnamed: 3  \
# count   1085.000000       888.000000           1084         0.0
# unique          NaN              NaN             43         NaN
# top             NaN              NaN      2/27/2020         NaN
# freq            NaN              NaN             91         NaN
# mean     543.000000        48.841216            NaN         NaN
# std      313.356825        78.853528            NaN         NaN
# min        1.000000         1.000000            NaN         NaN
# 25%      272.000000        11.000000            NaN         NaN
# 50%      543.000000        28.000000            NaN         NaN
# 75%      814.000000        67.250000            NaN         NaN
# max     1085.000000      1443.000000            NaN         NaN
#
#                                                summary     location country  \
# count                                             1080         1085    1085
# ...

# %%
COVID19_line_list_data.head()
# Out:
#    id  case_in_country reporting date  Unnamed: 3  \
# 0   1              NaN      1/20/2020         NaN
# 1   2              NaN      1/20/2020         NaN
# 2   3              NaN      1/21/2020         NaN
# 3   4              NaN      1/21/2020         NaN
# 4   5              NaN      1/21/2020         NaN
#
#                                              summary             location  \
# 0  First confirmed imported COVID-19 pneumonia pa...  Shenzhen, Guangdong
# 1  First confirmed imported COVID-19 pneumonia pa...             Shanghai
# 2  First confirmed imported cases in Zhejiang: pa...             Zhejiang
# 3  new confirmed imported COVID-19 pneumonia in T...              Tianjin
# 4  new confirmed imported COVID-19 pneumonia in T...              Tianjin
#
#   country  gender   age symptom_onset  ...  recovered symptom  \
# 0   China    male  66.0      01/03/20  ...          0     NaN
# 1   China  female  56.0     1/15/2020  ...          0     NaN
# ...

# %% [markdown]
# # time_series_covid_19_confirmed_US
#
# 美國各洲、確診

# %%
time_series_covid_19_confirmed_US = pd.read_csv("./time_series_covid_19_confirmed_US.csv")
time_series_covid_19_deaths_US  = pd.read_csv("time_series_covid_19_deaths_US.csv")

time_series_covid_19_confirmed_US.shape
# Out:
# (3340, 310)

# %%
time_series_covid_19_confirmed_US.head()
# Out:
#         UID iso2 iso3  code3    FIPS   Admin2 Province_State Country_Region  \
# 0  84001001   US  USA    840  1001.0  Autauga        Alabama             US
# 1  84001003   US  USA    840  1003.0  Baldwin        Alabama             US
# 2  84001005   US  USA    840  1005.0  Barbour        Alabama             US
# 3  84001007   US  USA    840  1007.0     Bibb        Alabama             US
# 4  84001009   US  USA    840  1009.0   Blount        Alabama             US
#
#          Lat      Long_  ... 11/6/20  11/7/20  11/8/20  11/9/20  11/10/20  \
# 0  32.539527 -86.644082  ...    2242     2267     2283     2304      2328
# 1  30.727750 -87.722071  ...    7134     7188     7226     7263      7348
# 2  31.868263 -85.387129  ...    1090     1092     1095     1098      1107
# 3  32.996421 -87.125115  ...     917      924      926      932       948
# 4  33.982109 -86.567906  ...    2253     2286     2297     2335      2378
#
#    11/11/20  11/12/20  11/13/20  11/14/20  11/15/20
# ...

# %% [markdown]
# # Population by Country - 2020
#
# from : https://www.kaggle.com/tanuprabhu/population-by-country-2020

# %%
population_by_country_2020 = pd.read_csv("population_by_country_2020.csv")

population_by_country_2020.describe(include="all")
# Out:
#        Country (or dependency)  Population (2020) Yearly Change    Net Change  \
# count                      235       2.350000e+02           235  2.350000e+02
# unique                     235                NaN           174           NaN
# top               Saudi Arabia                NaN        1.48 %           NaN
# freq                         1                NaN             4           NaN
# mean                       NaN       3.322744e+07           NaN  3.460878e+05
# std                        NaN       1.353034e+08           NaN  1.128260e+06
# min                        NaN       8.010000e+02           NaN -3.838400e+05
# 25%                        NaN       3.994905e+05           NaN  4.240000e+02
# 50%                        NaN       5.460109e+06           NaN  3.917000e+04
# 75%                        NaN       2.067170e+07           NaN  2.496600e+05
# max                        NaN       1.440298e+09           NaN  1.358663e+07
#
# ...

# %%
population_by_country_2020.head()
# Out:
#   Country (or dependency)  Population (2020) Yearly Change  Net Change  \
# 0                   China         1440297825        0.39 %     5540090
# 1                   India         1382345085        0.99 %    13586631
# 2           United States          331341050        0.59 %     1937734
# 3               Indonesia          274021604        1.07 %     2898047
# 4                Pakistan          221612785        2.00 %     4327022
#
#    Density (P/Km²)  Land Area (Km²)  Migrants (net) Fert. Rate Med. Age  \
# 0              153          9388211       -348399.0        1.7       38
# 1              464          2973190       -532687.0        2.2       28
# 2               36          9147420        954806.0        1.8       38
# 3              151          1811570        -98955.0        2.3       30
# 4              287           770880       -233379.0        3.6       23
#
#   Urban Pop % World Share
# 0        61 %     18.47 %
# 1        35 %     17.70 %
# ...
